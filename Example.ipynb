# %% [markdown]
# # Anthill library
#
# developed as part of spring 2020 CMSE802
#
# Code has been linted using pylint and autopep8:
#
# ```bash
# pylint anthill
# ```
#
# Documentation has been generated using:
#
# ```bash
# pdoc --force --html --output-dir ./docs anthill
# ```
#
# Tests can be run using:
#
# ```bash
# pytest
# ```

# %%
# %matplotlib inline
from ants import anthill
# Out:
# This is hte file you want!

# %%
hill = anthill.Anthill()

# %%
hill.simulate(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c53711491d43> in <module>
# ----> 1 hill.simulate(100)
#
# ~\Dropbox\Math\Teaching\CMSE802\ants-CMSE802-s21\ants\anthill.py in simulate(self, iterations)
#     134             for ant in self.Ants:
#     135                 ant.move(self.getneighbors(ant.loc))
# --> 136                 if ant.loc[0] < 0:
#     137                     ant.loc[0] = 0
#     138                 if ant.loc[0] == worldshape[0]:
#
# ~\Dropbox\Math\Teaching\CMSE802\ants-CMSE802-s21\ants\anthill.py in move(self, neighbors)
#      65         else:
#      66             direction = self.findfood(neighbors)
# ---> 67
#      68         # Write code here to update self.loc to move
#      69         # the ant in one of the four directions.
#
# ~\Dropbox\Math\Teaching\CMSE802\ants-CMSE802-s21\ants\anthill.py in findfood(self, neighbors)
#      44
#      45         return directionToGo
# ---> 46
#      47     def plot(self):
#      48         """Puts down a dot for this ant. Red means it has food,
#
# NameError: name 'directionToGo' is not defined

# %%
help(Anthill)
